# %% [markdown]
# 1. Fetch the artifact we just created (sample.csv) from W&B and read it with pandas:

# %%
import wandb
import pandas as pd
# Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/student/.netrc.
# wandb: Currently logged in as: jeff-forester (jeff-forester-western-governors-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Waiting for wandb.init()...
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/workspace/Project-Build-an-ML-Pipeline-Starter/src/eda/wandb/run-20260910_212734-enc56cjd</code>
# Syncing run <strong><a href='https://wandb.ai/jeff-forester-western-governors-university/nyc_airbnb/runs/enc56cjd' target="_blank">noble-cherry-2</a></strong> to <a href='https://wandb.ai/jeff-forester-western-governors-university/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jeff-forester-western-governors-university/nyc_airbnb' target="_blank">https://wandb.ai/jeff-forester-western-governors-university/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/jeff-forester-western-governors-university/nyc_airbnb/runs/enc56cjd' target="_blank">https://wandb.ai/jeff-forester-western-governors-university/nyc_airbnb/runs/enc56cjd</a>

# %% [markdown]
# 2. Explore the data in df

# %%
df.info()

# %%
df.describe()

# %%
df.head()

# %% [markdown]
# 3. What do you notice in the data? Look around and see what you can find.
#
# > For example, there are missing values in a few columns and the column `last_review` is a date but it is in string format. Look also at the `price` column, and note the outliers. There are some zeros and some very high prices. After talking to your stakeholders, you decide to consider from a minimum of `$10` to a maximum of `$350` per night.

# %% [markdown]
# 4. Fix some of the little problems we have found in the data with the following code:

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %% [markdown]
# Note how we did not impute missing values. We will do that in the inference pipeline, so we will be able to handle missing values also in production.

# %% [markdown]
# 5. Check with df.info() that all obvious problems have been solved

# %%
df.info()

# %% [markdown]
# 6. Terminate the run by running `run.finish()`

# %%
run.finish()

# %% [markdown]
# 7. Save the notebook.
